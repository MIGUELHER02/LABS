# %%
import pandas as pd

# %%
datas = pd.read_csv("fao.csv")

# %%
datas
# Out:
#    Código Ámbito                          Ámbito  Código área      Área  \
# 0             FS  Datos de Seguridad Alimentaria           95  Honduras
# 1             FS  Datos de Seguridad Alimentaria           95  Honduras
# 2             FS  Datos de Seguridad Alimentaria           95  Honduras
# 3             FS  Datos de Seguridad Alimentaria           95  Honduras
# 4             FS  Datos de Seguridad Alimentaria           95  Honduras
# 5             FS  Datos de Seguridad Alimentaria           95  Honduras
# 6             FS  Datos de Seguridad Alimentaria           95  Honduras
# 7             FS  Datos de Seguridad Alimentaria           95  Honduras
# 8             FS  Datos de Seguridad Alimentaria           95  Honduras
# 9             FS  Datos de Seguridad Alimentaria           95  Honduras
# 10            FS  Datos de Seguridad Alimentaria           95  Honduras
# 11            FS  Datos de Seguridad Alimentaria           95  Honduras
# ...
